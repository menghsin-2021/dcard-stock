# %%
import pandas as pd
import requests

# %%
# # 建立空 DataFrame
# data = pd.DataFrame(columns=['ID', 'title', 'createdAt', 'updatedAt', 'commentCount',
#              'forumName', 'forumAlias', 'likeCount', 'reactions', 'topics'])

# 股版依時間順序前100則文章url
url = 'https://www.dcard.tw/service/api/v2/forums/stock/posts?limit=100'

        
# 輸入 json 資料中一筆字典並建立 dataFrame
def dj_to_df(dj):
    df = pd.DataFrame(data= 
       [{'ID': dj['id'],                          # 編號
        'title': dj['title'],                     # 標題
        'createdAt': dj['createdAt'],             # 發布時間
        'updatedAt': dj['updatedAt'],             # 更新時間
        'commentCount': dj['commentCount'],       # 留言數
        'forumName': dj['forumName'],             # 論壇分類(中文)
        'forumAlias': dj['forumAlias'],           # 論壇分類(英文)
        'likeCount': dj['likeCount'],             # 心情數量
        'reactions': dj['reactions'],             # 心情細項
        'topics': dj['topics']}],                 # 標籤
    columns=['ID', 'title', 'createdAt', 'updatedAt', 'commentCount',
             'forumName', 'forumAlias', 'likeCount', 'reactions', 'topics'])
    return df

# 透過request套件抓下網址資料
def crawl(url):
    df = pd.DataFrame(columns=['ID', 'title', 'createdAt', 'updatedAt', 'commentCount',
             'forumName', 'forumAlias', 'likeCount', 'reactions', 'topics'])
    r = requests.get(url)
    if r.status_code != requests.codes.ok:
        raise SystemExit # 結束程式
        
    for i in range(len(r.json())):
        dj = r.json()[i]    
        df = df.append(dj_to_df(dj), ignore_index=True)
    
    return df

data = crawl(url)

for i in range(1):
    try:
        last = str(int(data.tail(1).ID)) # 找出爬出資料的最後一筆ID
        after_url = 'https://www.dcard.tw/service/api/v2/forums/stock/posts?limit=100&before=' + last
        data = data.append(crawl(after_url), ignore_index=True)
    except:
        print ('finish')

data
# Out:
#             ID                  title                 createdAt  \
# 0    236669177          #分享 航運我進了嗎？..  2021-08-07T15:02:57.172Z
# 1    236668620                 股票新手建議  2021-08-07T13:52:30.191Z
# 2    236668160          徵求 大昌或富邦證券營業員  2021-08-07T12:53:01.548Z
# 3    236667983            #分享 類股技術面分享  2021-08-07T12:25:55.709Z
# 4    236667653       #分享 本週千張大戶增加3%以上  2021-08-07T11:43:09.574Z
# ..         ...                    ...                       ...
# 195  236629148              #分享 電動車玻璃  2021-08-02T08:35:05.220Z
# 196  236629030   #請益 今天長榮萬海是傳說中的逃命波嗎?  2021-08-02T08:17:03.532Z
# 197  236628975       08/02 三大法人買賣金額統計  2021-08-02T08:09:11.082Z
# 198  236628928  #分享 2021/08/02 大盤技術分析  2021-08-02T08:01:59.770Z
# 199  236628864                 #請益 康普  2021-08-02T07:52:27.590Z
#
#                     updatedAt commentCount forumName forumAlias likeCount  \
# 0    2021-08-07T15:03:15.724Z            3        股票      stock         4
# 1    2021-08-07T13:52:30.191Z            8        股票      stock         1
# 2    2021-08-07T12:53:01.548Z            7        股票      stock         1
# 3    2021-08-07T12:45:35.110Z            0        股票      stock         4
# 4    2021-08-07T11:43:09.574Z            4        股票      stock         5
# ..                        ...          ...       ...        ...       ...
# 195  2021-08-02T08:35:05.220Z            8        股票      stock         6
# 196  2021-08-03T06:56:37.174Z          286        股票      stock       227
# 197  2021-08-02T08:09:11.082Z            0        股票      stock         7
# 198  2021-08-02T08:01:59.770Z            0        股票      stock         4
# 199  2021-08-02T07:52:27.590Z           19        股票      stock        11
#
#                                              reactions                  topics
# 0    [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03'...        [航運, 股票, 理財, 波段]
# 1    [{'id': '514c2569-fd53-4d9d-a415-bf0f88e7329f'...        [新手, 建議, 投資, 股票]
# 2    [{'id': '514c2569-fd53-4d9d-a415-bf0f88e7329f'...        [富邦, 證券, 美股, 股票]
# 3    [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03'...  [投資, 股票, 台股, 技術分析, 理財]
# 4    [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03'...    [大戶, 投資, 股票, 理財, 台股]
# ..                                                 ...                     ...
# 195  [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03'...   [電動車, 玻璃, 投資, 股票, 台股]
# 196  [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03'...            [投資, 股票, 理財]
# 197  [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03'...              [台股, 三大法人]
# 198  [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03'...  [技術分析, 投資, 股票, 理財, 台股]
# 199  [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03'...            [投資, 股票, 新手]
#
# [200 rows x 10 columns]

# %%
# 將資料存到桌面
# df.to_excel('C:/Users/TLYu0419/Desktop/Dcard.xlsx')
# Out:
# https://www.dcard.tw/service/api/v2/forums/stock/posts?limit=100&before=236646311
